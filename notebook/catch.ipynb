# %% [markdown]
# ## 캐치 - 면접 후기 리스트 크롤링

# %%
import requests
from bs4 import BeautifulSoup as BS
import json
import pandas as pd

# %%
company = '삼성'
pageSize = 5

# %%
url = f'https://www.catch.co.kr/api/v1.0/jobn/interview/comp/mainQuestionList?JobCode=&RecruitGubun=&Year=&Term=&JinhakCode=&Keyword={company}&CurPage=1&PageSize={pageSize}'
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36'}

# %%
r = requests.get(url, headers=head)

# %%
bs = BS(r.text)

# %%
text = bs.find('p')

# %% [markdown]
# ## 면접 후기 크롤링 (질문 포함)

# %%
url = 'https://www.catch.co.kr/api/v1.0/jobn/interview/comp/review/46313'
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36'}
r = requests.get(url, headers=head)
bs = BS(r.text)

# %%
import pandas as pd

json.loads(bs.find('p').text)['question']
# Out:
# [{'InterviewID': 46313,
#   'idx': 140466,
#   'Question': '근처 유명 맛집 식당에 기업금융 담당자로서 유치 방안을 기안해주세요.(공통질문)'},
#  {'InterviewID': 46313,
#   'idx': 140467,
#   'Question': '자유롭게 연차를 사용하는 것에 대해 어떻게 생각하시나요? (공통질문)'},
#  {'InterviewID': 46313,
#   'idx': 140468,
#   'Question': '굉장히 calm 하시고 차분하신데, 혹시 고객을 대하신 경험은 있으신가요? (개별)'}]

# %%
url = 'https://www.catch.co.kr/api/v1.0/jobn/interview/comp/reviewList/840130?CurPage=1&PageSize=85&JobCode=&RecruitGubun=&IsPass=&ProcessType='
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36'}
r = requests.get(url, headers=head)
r.text

bs = BS(r.text)
pd.DataFrame(json.loads(bs.find('p').text)['review'])
# Out:
#     InterviewID  JobCodeName  Year Term RecruitGubun  Atmosphere  Level  \
# 0         46502         일반영업  2024  하반기            1           1      4
# 1         46313  증권/투자/펀드/외환  2024  하반기            1           2      4
# 2         45339         일반영업  2024  하반기            1           1      2
# 3         44869     응용프로그램개발  2024  하반기            1           3      3
# 4         44671         일반영업  2024  하반기            1           3      3
# ..          ...          ...   ...  ...          ...         ...    ...
# 80         8391         일반영업  2022  하반기            1           3      4
# 81         8254         일반영업  2022  하반기            1           3      2
# 82         8177         일반영업  2022  하반기            1           1      3
# 83         7978         일반영업  2022  하반기            1           2      4
# 84         7674      빅데이터/AI  2022  하반기            1           2      3
#
#    AppealName IsPass DurationCode  \
# 0       소통/협력      N            5
# ...
